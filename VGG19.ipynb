# %% [markdown]
# ## VGG 19 Model Implementation for Sign Language  detection

# %%
from google.colab import drive
drive.mount('/content/drive')
#/content/drive/MyDrive/model_weights_vgg19_signLanguageDetection.h5
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d grassknoted/asl-alphabet
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading asl-alphabet.zip to /content
#  99% 1.01G/1.03G [00:11<00:00, 93.4MB/s]
# 100% 1.03G/1.03G [00:11<00:00, 92.5MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/asl-alphabet.zip','r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
# Load Data
import os
import cv2
import numpy as np

# Data Visualisation
import matplotlib.pyplot as plt

# Model Training
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import VGG16

# Warning
import warnings
warnings.filterwarnings("ignore")

# Main
import os
import glob
import cv2
import numpy as np
import pandas as pd
import gc
import string
import time
import random
from PIL import Image
from tqdm import tqdm
tqdm.pandas()

# Visualization
import matplotlib
import matplotlib.pyplot as plt




from sklearn.manifold import TSNE
# Model
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten, Dropout
from keras.models import load_model, Model
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
train_dir = "/content/asl_alphabet_train/asl_alphabet_train"
test_dir = "/content/asl_alphabet_test/asl_alphabet_test"

# %%
import pathlib
data = pathlib.Path(train_dir)
data
# Out:
# PosixPath('/content/asl_alphabet_train/asl_alphabet_train')

# %%
image_count = len(list(data.glob('*/*.jpg')))
image_count
# Out:
# 87000

# %%
A = list(data.glob('A/*'))[0:200]
len(A)
# Out:
# 200

# %%
diction = {
    'A' : list(data.glob('A/*'))[:400],
    'B' : list(data.glob('B/*'))[:400],
    'C' : list(data.glob('C/*'))[:400],
    'D' : list(data.glob('D/*'))[:400],
    'E' : list(data.glob('E/*'))[:400]
    #'F' : list(data.glob('F/*'))[:500]
}
len(diction['A'])
# Out:
# 400

# %%
labels_diction = {
    'A' : 0,
    'B' : 1,
    'C' : 2,
    'D' : 3,
    'E' : 4,
    #'F' : 5
}
labels_diction
# Out:
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4}

# %%
for keyname,images in diction.items() :
  print(keyname)
  print(len(images))
# Out:
# A
# 400
# B
# 400
# C
# 400
# D
# 400
# E
# 400

# %%
x,y = [] , []
for keyname,images in diction.items() :
  for image in images : # we know that the term image is referring to a posixpath in diction dictionary
    img = cv2.imread(str(image)) # now we are using that path and converting them to numpy arrays using imread fundtion
    resized_img = cv2.resize(img,(224,224))
    x.append(resized_img) # we are storing resized perfect images in x list
    y.append(labels_diction[keyname]) # and we are adding its particular label in y list

# %%
# converting x,y lists into numpy arrays for further usage
x = np.array(x)
y = np.array(y)

# %%
x.shape
# Out:
# (2000, 224, 224, 3)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 0)

# %%
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)
#check from here if any error raises

# %%
x_train_scaled = x_train / 255.0
x_test_scaled = x_test / 255.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from tensorflow import keras
from keras import datasets, layers, models

# %%
# #The above output are the sizes of lists before augmentation
# #Now we will perform data augmentation to increase the no of samples and better training
# data_augmentation = keras.Sequential([
#    layers.experimental.preprocessing.RandomRotation(0.1),
#    layers.experimental.preprocessing.RandomContrast(0.1),
#    layers.experimental.preprocessing.RandomZoom(0.1),
# ])

# %%
# Initialising the model
model = models.Sequential()

#model.add(data_augmentation)
# Stage 1
model.add(layers.Conv2D(input_shape = (224, 224, 3), filters = 64, kernel_size = (3, 3), strides=(1, 1), activation = 'relu', padding='same'))
model.add(layers.Conv2D(filters = 64, kernel_size = (3, 3), strides=(1, 1), activation = 'relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))


# Stage 2
model.add(layers.Conv2D(filters = 128, kernel_size = (3, 3), strides=(1, 1), activation = 'relu', padding='same'))
model.add(layers.Conv2D(filters = 128, kernel_size = (3, 3), strides=(1, 1), activation = 'relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))


# Stage 3
model.add(layers.Conv2D(filters = 256, kernel_size = (3, 3), strides=(1, 1), activation = 'relu', padding='same'))
model.add(layers.Conv2D(filters = 256, kernel_size = (3, 3), strides=(1, 1), activation = 'relu', padding='same'))
model.add(layers.Conv2D(filters = 256, kernel_size = (3, 3), strides=(1, 1), activation = 'relu', padding='same'))
model.add(layers.Conv2D(filters = 256, kernel_size = (3, 3), strides=(1, 1), activation = 'relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))


# Stage 4
model.add(layers.Conv2D(filters = 512, kernel_size = (3, 3), strides=(1, 1), activation = 'relu', padding='same'))
model.add(layers.Conv2D(filters = 512, kernel_size = (3, 3), strides=(1, 1), activation = 'relu', padding='same'))
model.add(layers.Conv2D(filters = 512, kernel_size = (3, 3), strides=(1, 1), activation = 'relu', padding='same'))
model.add(layers.Conv2D(filters = 512, kernel_size = (3, 3), strides=(1, 1), activation = 'relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))


# Stage 5
model.add(layers.Conv2D(filters = 512, kernel_size = (3, 3), strides=(1, 1), activation = 'relu', padding='same'))
model.add(layers.Conv2D(filters = 512, kernel_size = (3, 3), strides=(1, 1), activation = 'relu', padding='same'))
model.add(layers.Conv2D(filters = 512, kernel_size = (3, 3), strides=(1, 1), activation = 'relu', padding='same'))
model.add(layers.Conv2D(filters = 512, kernel_size = (3, 3), strides=(1, 1), activation = 'relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))


# Stage 6
model.add(layers.Flatten())
model.add(layers.Dense(units = 4096, activation='relu'))
model.add(layers.Dense(units = 4096, activation='relu'))
model.add(layers.Dense(units = 6, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 64)      36928
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 64)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 128)     73856
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 128)     147584
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 256)       590080
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 256)       590080
#
#  conv2d_7 (Conv2D)           (None, 56, 56, 256)       590080
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 256)      0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 512)       1180160
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 512)      0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_13 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_14 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_15 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 4096)              102764544
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 6)                 24582
#
# =================================================================
# Total params: 139,594,822
# Trainable params: 139,594,822
# Non-trainable params: 0
# _________________________________________________________________

# %%
#model.compile(loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),optimizer='adam',metrics=["accuracy"])

# %%
from keras.optimizers import SGD
from keras.callbacks import LearningRateScheduler

# %%
epochs = 120
initial_lrate = 0.01

def decay(epoch, steps=100):
    initial_lrate = 0.01
    drop = 0.96
    epochs_drop = 8
    lrate = initial_lrate * drop**(1+epoch)/epochs_drop
    return lrate

sgd = SGD(lr=initial_lrate, momentum=0.9, nesterov=False)

lr_sc = LearningRateScheduler(decay, verbose=1)

model.compile(loss='sparse_categorical_crossentropy', loss_weights=[1, 0.3, 0.3], optimizer=sgd, metrics=['accuracy'],)

# %%
#history = model.fit(x_train_scaled, y_train, epochs=40)

# %%
# Fitting the training data into the model
history = model.fit(x_train_scaled, y_train,validation_data=(x_test,y_test),  epochs=epochs,callbacks=[lr_sc])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.00017616888227273004.
# Epoch 48/120
# 47/47 [==============================] - 27s 566ms/step - loss: 0.2097 - accuracy: 0.9240 - val_loss: 145.6567 - val_accuracy: 0.8340 - lr: 1.7617e-04
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.00016912212698182082.
# Epoch 49/120
# 47/47 [==============================] - 26s 563ms/step - loss: 0.1540 - accuracy: 0.9433 - val_loss: 200.9086 - val_accuracy: 0.7740 - lr: 1.6912e-04
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.00016235724190254798.
# Epoch 50/120
# 47/47 [==============================] - 26s 562ms/step - loss: 0.1517 - accuracy: 0.9433 - val_loss: 163.1414 - val_accuracy: 0.8060 - lr: 1.6236e-04
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.00015586295222644607.
# Epoch 51/120
# 47/47 [==============================] - 26s 563ms/step - loss: 0.1268 - accuracy: 0.9520 - val_loss: 143.6469 - val_accuracy: 0.8400 - lr: 1.5586e-04
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.00014962843413738821.
# Epoch 52/120
# 47/47 [==============================] - 26s 562ms/step - loss: 0.0740 - accuracy: 0.9773 - val_loss: 151.0741 - val_accuracy: 0.8400 - lr: 1.4963e-04
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.00014364329677189267.
# Epoch 53/120
# 47/47 [==============================] - 27s 566ms/step - loss: 0.0386 - accuracy: 0.9900 - val_loss: 203.5670 - val_accuracy: 0.8320 - lr: 1.4364e-04
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.00013789756490101697.
# Epoch 54/120
# 47/47 [==============================] - 26s 562ms/step - loss: 0.0398 - accuracy: 0.9873 - val_loss: 210.8479 - val_accuracy: 0.8460 - lr: 1.3790e-04
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.00013238166230497626.
# Epoch 55/120
# 47/47 [==============================] - 26s 562ms/step - loss: 0.0287 - accuracy: 0.9913 - val_loss: 147.7089 - val_accuracy: 0.8780 - lr: 1.3238e-04
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.00012708639581277724.
# Epoch 56/120
# 47/47 [==============================] - 26s 563ms/step - loss: 0.0918 - accuracy: 0.9687 - val_loss: 218.3382 - val_accuracy: 0.8380 - lr: 1.2709e-04
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.00012200293998026612.
# Epoch 57/120
# 47/47 [==============================] - 26s 565ms/step - loss: 0.0985 - accuracy: 0.9620 - val_loss: 145.4198 - val_accuracy: 0.8540 - lr: 1.2200e-04
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.00011712282238105549.
# Epoch 58/120
# 47/47 [==============================] - 27s 565ms/step - loss: 0.0297 - accuracy: 0.9907 - val_loss: 148.2456 - val_accuracy: 0.8660 - lr: 1.1712e-04
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.00011243790948581325.
# Epoch 59/120
# 47/47 [==============================] - 26s 563ms/step - loss: 0.0175 - accuracy: 0.9953 - val_loss: 154.6313 - val_accuracy: 0.8640 - lr: 1.1244e-04
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.00010794039310638073.
# Epoch 60/120
# 47/47 [==============================] - 26s 561ms/step - loss: 0.0213 - accuracy: 0.9947 - val_loss: 211.9416 - val_accuracy: 0.8440 - lr: 1.0794e-04
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.00010362277738212549.
# Epoch 61/120
# 47/47 [==============================] - 26s 560ms/step - loss: 0.0151 - accuracy: 0.9960 - val_loss: 177.0334 - val_accuracy: 0.8740 - lr: 1.0362e-04
#
# Epoch 62: LearningRateScheduler setting learning rate to 9.947786628684046e-05.
# Epoch 62/120
# 47/47 [==============================] - 26s 563ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 162.8326 - val_accuracy: 0.8720 - lr: 9.9478e-05
#
# Epoch 63: LearningRateScheduler setting learning rate to 9.549875163536683e-05.
# Epoch 63/120
# 47/47 [==============================] - 27s 566ms/step - loss: 0.0046 - accuracy: 0.9993 - val_loss: 207.0946 - val_accuracy: 0.8580 - lr: 9.5499e-05
#
# Epoch 64: LearningRateScheduler setting learning rate to 9.167880156995218e-05.
# Epoch 64/120
# 47/47 [==============================] - 26s 562ms/step - loss: 0.0092 - accuracy: 0.9987 - val_loss: 207.2590 - val_accuracy: 0.8540 - lr: 9.1679e-05
#
# Epoch 65: LearningRateScheduler setting learning rate to 8.801164950715408e-05.
# Epoch 65/120
# 47/47 [==============================] - 26s 561ms/step - loss: 0.0032 - accuracy: 0.9993 - val_loss: 166.4419 - val_accuracy: 0.8640 - lr: 8.8012e-05
#
# Epoch 66: LearningRateScheduler setting learning rate to 8.449118352686791e-05.
# Epoch 66/120
# 47/47 [==============================] - 26s 561ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 180.2965 - val_accuracy: 0.8780 - lr: 8.4491e-05
#
# Epoch 67: LearningRateScheduler setting learning rate to 8.11115361857932e-05.
# Epoch 67/120
# 47/47 [==============================] - 26s 563ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 191.8511 - val_accuracy: 0.8740 - lr: 8.1112e-05
#
# Epoch 68: LearningRateScheduler setting learning rate to 7.786707473836146e-05.
# Epoch 68/120
# 47/47 [==============================] - 26s 565ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 188.6333 - val_accuracy: 0.8760 - lr: 7.7867e-05
#
# Epoch 69: LearningRateScheduler setting learning rate to 7.4752391748827e-05.
# Epoch 69/120
# 47/47 [==============================] - 27s 566ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 160.3248 - val_accuracy: 0.8840 - lr: 7.4752e-05
#
# Epoch 70: LearningRateScheduler setting learning rate to 7.176229607887392e-05.
# Epoch 70/120
# 47/47 [==============================] - 26s 563ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 196.8067 - val_accuracy: 0.8760 - lr: 7.1762e-05
#
# Epoch 71: LearningRateScheduler setting learning rate to 6.889180423571896e-05.
# Epoch 71/120
# 47/47 [==============================] - 26s 561ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 184.9920 - val_accuracy: 0.8760 - lr: 6.8892e-05
#
# Epoch 72: LearningRateScheduler setting learning rate to 6.61361320662902e-05.
# Epoch 72/120
# 47/47 [==============================] - 26s 564ms/step - loss: 9.8701e-04 - accuracy: 1.0000 - val_loss: 188.6204 - val_accuracy: 0.8800 - lr: 6.6136e-05
#
# Epoch 73: LearningRateScheduler setting learning rate to 6.349068678363859e-05.
# Epoch 73/120
# 47/47 [==============================] - 26s 564ms/step - loss: 9.2043e-04 - accuracy: 1.0000 - val_loss: 188.0875 - val_accuracy: 0.8800 - lr: 6.3491e-05
#
# Epoch 74: LearningRateScheduler setting learning rate to 6.095105931229304e-05.
# Epoch 74/120
# 47/47 [==============================] - 26s 560ms/step - loss: 9.1139e-04 - accuracy: 1.0000 - val_loss: 188.8051 - val_accuracy: 0.8800 - lr: 6.0951e-05
#
# Epoch 75: LearningRateScheduler setting learning rate to 5.851301693980132e-05.
# Epoch 75/120
# 47/47 [==============================] - 26s 562ms/step - loss: 8.5986e-04 - accuracy: 1.0000 - val_loss: 191.5575 - val_accuracy: 0.8800 - lr: 5.8513e-05
#
# Epoch 76: LearningRateScheduler setting learning rate to 5.617249626220926e-05.
# Epoch 76/120
# 47/47 [==============================] - 26s 562ms/step - loss: 8.2628e-04 - accuracy: 1.0000 - val_loss: 191.5098 - val_accuracy: 0.8780 - lr: 5.6172e-05
#
# Epoch 77: LearningRateScheduler setting learning rate to 5.3925596411720896e-05.
# Epoch 77/120
# 47/47 [==============================] - 27s 566ms/step - loss: 8.2513e-04 - accuracy: 1.0000 - val_loss: 190.8090 - val_accuracy: 0.8800 - lr: 5.3926e-05
#
# Epoch 78: LearningRateScheduler setting learning rate to 5.176857255525205e-05.
# Epoch 78/120
# 47/47 [==============================] - 26s 564ms/step - loss: 7.5238e-04 - accuracy: 1.0000 - val_loss: 194.3224 - val_accuracy: 0.8780 - lr: 5.1769e-05
#
# Epoch 79: LearningRateScheduler setting learning rate to 4.969782965304197e-05.
# Epoch 79/120
# 47/47 [==============================] - 26s 563ms/step - loss: 7.4768e-04 - accuracy: 1.0000 - val_loss: 193.4421 - val_accuracy: 0.8800 - lr: 4.9698e-05
#
# Epoch 80: LearningRateScheduler setting learning rate to 4.7709916466920284e-05.
# Epoch 80/120
# 47/47 [==============================] - 26s 563ms/step - loss: 7.0377e-04 - accuracy: 1.0000 - val_loss: 194.4213 - val_accuracy: 0.8800 - lr: 4.7710e-05
#
# Epoch 81: LearningRateScheduler setting learning rate to 4.580151980824348e-05.
# Epoch 81/120
# 47/47 [==============================] - 26s 561ms/step - loss: 6.8663e-04 - accuracy: 1.0000 - val_loss: 195.1316 - val_accuracy: 0.8780 - lr: 4.5802e-05
#
# Epoch 82: LearningRateScheduler setting learning rate to 4.396945901591373e-05.
# Epoch 82/120
# 47/47 [==============================] - 26s 564ms/step - loss: 6.7865e-04 - accuracy: 1.0000 - val_loss: 197.3625 - val_accuracy: 0.8800 - lr: 4.3969e-05
#
# Epoch 83: LearningRateScheduler setting learning rate to 4.221068065527719e-05.
# Epoch 83/120
# 47/47 [==============================] - 26s 565ms/step - loss: 6.5162e-04 - accuracy: 1.0000 - val_loss: 195.5501 - val_accuracy: 0.8780 - lr: 4.2211e-05
#
# Epoch 84: LearningRateScheduler setting learning rate to 4.05222534290661e-05.
# Epoch 84/120
# 47/47 [==============================] - 26s 564ms/step - loss: 6.3799e-04 - accuracy: 1.0000 - val_loss: 196.8859 - val_accuracy: 0.8800 - lr: 4.0522e-05
#
# Epoch 85: LearningRateScheduler setting learning rate to 3.890136329190345e-05.
# Epoch 85/120
# 47/47 [==============================] - 26s 562ms/step - loss: 6.1512e-04 - accuracy: 1.0000 - val_loss: 197.5526 - val_accuracy: 0.8780 - lr: 3.8901e-05
#
# Epoch 86: LearningRateScheduler setting learning rate to 3.7345308760227315e-05.
# Epoch 86/120
# 47/47 [==============================] - 26s 564ms/step - loss: 6.1885e-04 - accuracy: 1.0000 - val_loss: 198.0460 - val_accuracy: 0.8800 - lr: 3.7345e-05
#
# Epoch 87: LearningRateScheduler setting learning rate to 3.585149640981822e-05.
# Epoch 87/120
# 47/47 [==============================] - 27s 567ms/step - loss: 6.0481e-04 - accuracy: 1.0000 - val_loss: 197.8431 - val_accuracy: 0.8780 - lr: 3.5851e-05
#
# Epoch 88: LearningRateScheduler setting learning rate to 3.441743655342549e-05.
# Epoch 88/120
# 47/47 [==============================] - 26s 563ms/step - loss: 5.8674e-04 - accuracy: 1.0000 - val_loss: 198.8034 - val_accuracy: 0.8780 - lr: 3.4417e-05
#
# Epoch 89: LearningRateScheduler setting learning rate to 3.3040739091288465e-05.
# Epoch 89/120
# 47/47 [==============================] - 26s 562ms/step - loss: 5.7957e-04 - accuracy: 1.0000 - val_loss: 198.2558 - val_accuracy: 0.8780 - lr: 3.3041e-05
#
# Epoch 90: LearningRateScheduler setting learning rate to 3.1719109527636925e-05.
# Epoch 90/120
# 47/47 [==============================] - 26s 562ms/step - loss: 5.6561e-04 - accuracy: 1.0000 - val_loss: 200.2206 - val_accuracy: 0.8780 - lr: 3.1719e-05
#
# Epoch 91: LearningRateScheduler setting learning rate to 3.0450345146531447e-05.
# Epoch 91/120
# 47/47 [==============================] - 26s 563ms/step - loss: 5.5165e-04 - accuracy: 1.0000 - val_loss: 199.8611 - val_accuracy: 0.8780 - lr: 3.0450e-05
#
# Epoch 92: LearningRateScheduler setting learning rate to 2.9232331340670186e-05.
# Epoch 92/120
# 47/47 [==============================] - 27s 567ms/step - loss: 5.4699e-04 - accuracy: 1.0000 - val_loss: 200.0425 - val_accuracy: 0.8780 - lr: 2.9232e-05
#
# Epoch 93: LearningRateScheduler setting learning rate to 2.806303808704338e-05.
# Epoch 93/120
# 47/47 [==============================] - 26s 565ms/step - loss: 5.4220e-04 - accuracy: 1.0000 - val_loss: 200.4976 - val_accuracy: 0.8780 - lr: 2.8063e-05
#
# Epoch 94: LearningRateScheduler setting learning rate to 2.6940516563561646e-05.
# Epoch 94/120
# 47/47 [==============================] - 26s 562ms/step - loss: 5.3244e-04 - accuracy: 1.0000 - val_loss: 200.6512 - val_accuracy: 0.8780 - lr: 2.6941e-05
#
# Epoch 95: LearningRateScheduler setting learning rate to 2.5862895901019177e-05.
# Epoch 95/120
# 47/47 [==============================] - 26s 565ms/step - loss: 5.2575e-04 - accuracy: 1.0000 - val_loss: 201.5357 - val_accuracy: 0.8780 - lr: 2.5863e-05
#
# Epoch 96: LearningRateScheduler setting learning rate to 2.4828380064978408e-05.
# Epoch 96/120
# 47/47 [==============================] - 27s 566ms/step - loss: 5.2347e-04 - accuracy: 1.0000 - val_loss: 201.6118 - val_accuracy: 0.8780 - lr: 2.4828e-05
#
# Epoch 97: LearningRateScheduler setting learning rate to 2.3835244862379272e-05.
# Epoch 97/120
# 47/47 [==============================] - 26s 564ms/step - loss: 5.1913e-04 - accuracy: 1.0000 - val_loss: 200.9408 - val_accuracy: 0.8780 - lr: 2.3835e-05
#
# Epoch 98: LearningRateScheduler setting learning rate to 2.28818350678841e-05.
# Epoch 98/120
# 47/47 [==============================] - 26s 562ms/step - loss: 5.0991e-04 - accuracy: 1.0000 - val_loss: 201.9245 - val_accuracy: 0.8780 - lr: 2.2882e-05
#
# Epoch 99: LearningRateScheduler setting learning rate to 2.1966561665168737e-05.
# Epoch 99/120
# 47/47 [==============================] - 26s 562ms/step - loss: 5.0493e-04 - accuracy: 1.0000 - val_loss: 201.3407 - val_accuracy: 0.8780 - lr: 2.1967e-05
#
# Epoch 100: LearningRateScheduler setting learning rate to 2.1087899198561984e-05.
# Epoch 100/120
# 47/47 [==============================] - 26s 562ms/step - loss: 4.9982e-04 - accuracy: 1.0000 - val_loss: 202.3473 - val_accuracy: 0.8780 - lr: 2.1088e-05
#
# Epoch 101: LearningRateScheduler setting learning rate to 2.0244383230619505e-05.
# Epoch 101/120
# 47/47 [==============================] - 27s 566ms/step - loss: 4.9448e-04 - accuracy: 1.0000 - val_loss: 202.7739 - val_accuracy: 0.8780 - lr: 2.0244e-05
#
# Epoch 102: LearningRateScheduler setting learning rate to 1.9434607901394723e-05.
# Epoch 102/120
# 47/47 [==============================] - 26s 563ms/step - loss: 4.8999e-04 - accuracy: 1.0000 - val_loss: 202.4504 - val_accuracy: 0.8780 - lr: 1.9435e-05
#
# Epoch 103: LearningRateScheduler setting learning rate to 1.8657223585338934e-05.
# Epoch 103/120
# 47/47 [==============================] - 26s 564ms/step - loss: 4.8575e-04 - accuracy: 1.0000 - val_loss: 202.7664 - val_accuracy: 0.8780 - lr: 1.8657e-05
#
# Epoch 104: LearningRateScheduler setting learning rate to 1.7910934641925377e-05.
# Epoch 104/120
# 47/47 [==============================] - 26s 564ms/step - loss: 4.8102e-04 - accuracy: 1.0000 - val_loss: 202.8671 - val_accuracy: 0.8780 - lr: 1.7911e-05
#
# Epoch 105: LearningRateScheduler setting learning rate to 1.7194497256248362e-05.
# Epoch 105/120
# 47/47 [==============================] - 26s 561ms/step - loss: 4.7692e-04 - accuracy: 1.0000 - val_loss: 203.2589 - val_accuracy: 0.8780 - lr: 1.7194e-05
#
# Epoch 106: LearningRateScheduler setting learning rate to 1.6506717365998426e-05.
# Epoch 106/120
# 47/47 [==============================] - 26s 563ms/step - loss: 4.7454e-04 - accuracy: 1.0000 - val_loss: 203.1840 - val_accuracy: 0.8780 - lr: 1.6507e-05
#
# Epoch 107: LearningRateScheduler setting learning rate to 1.584644867135849e-05.
# Epoch 107/120
# 47/47 [==============================] - 27s 565ms/step - loss: 4.6922e-04 - accuracy: 1.0000 - val_loss: 203.3351 - val_accuracy: 0.8780 - lr: 1.5846e-05
#
# Epoch 108: LearningRateScheduler setting learning rate to 1.521259072450415e-05.
# Epoch 108/120
# 47/47 [==============================] - 26s 564ms/step - loss: 4.6767e-04 - accuracy: 1.0000 - val_loss: 203.5264 - val_accuracy: 0.8780 - lr: 1.5213e-05
#
# Epoch 109: LearningRateScheduler setting learning rate to 1.4604087095523982e-05.
# Epoch 109/120
# 47/47 [==============================] - 26s 563ms/step - loss: 4.6563e-04 - accuracy: 1.0000 - val_loss: 203.6103 - val_accuracy: 0.8780 - lr: 1.4604e-05
#
# Epoch 110: LearningRateScheduler setting learning rate to 1.401992361170302e-05.
# Epoch 110/120
# 47/47 [==============================] - 26s 561ms/step - loss: 4.6308e-04 - accuracy: 1.0000 - val_loss: 203.9604 - val_accuracy: 0.8780 - lr: 1.4020e-05
#
# Epoch 111: LearningRateScheduler setting learning rate to 1.34591266672349e-05.
# Epoch 111/120
# 47/47 [==============================] - 26s 561ms/step - loss: 4.5934e-04 - accuracy: 1.0000 - val_loss: 204.1368 - val_accuracy: 0.8780 - lr: 1.3459e-05
#
# Epoch 112: LearningRateScheduler setting learning rate to 1.2920761600545504e-05.
# Epoch 112/120
# 47/47 [==============================] - 26s 563ms/step - loss: 4.5745e-04 - accuracy: 1.0000 - val_loss: 204.0201 - val_accuracy: 0.8780 - lr: 1.2921e-05
#
# Epoch 113: LearningRateScheduler setting learning rate to 1.2403931136523684e-05.
# Epoch 113/120
# 47/47 [==============================] - 26s 562ms/step - loss: 4.5588e-04 - accuracy: 1.0000 - val_loss: 203.7910 - val_accuracy: 0.8780 - lr: 1.2404e-05
#
# Epoch 114: LearningRateScheduler setting learning rate to 1.1907773891062735e-05.
# Epoch 114/120
# 47/47 [==============================] - 26s 564ms/step - loss: 4.5340e-04 - accuracy: 1.0000 - val_loss: 204.1370 - val_accuracy: 0.8780 - lr: 1.1908e-05
#
# Epoch 115: LearningRateScheduler setting learning rate to 1.1431462935420225e-05.
# Epoch 115/120
# 47/47 [==============================] - 26s 564ms/step - loss: 4.5005e-04 - accuracy: 1.0000 - val_loss: 204.4028 - val_accuracy: 0.8780 - lr: 1.1431e-05
#
# Epoch 116: LearningRateScheduler setting learning rate to 1.0974204418003416e-05.
# Epoch 116/120
# 47/47 [==============================] - 26s 564ms/step - loss: 4.4674e-04 - accuracy: 1.0000 - val_loss: 204.7009 - val_accuracy: 0.8780 - lr: 1.0974e-05
#
# Epoch 117: LearningRateScheduler setting learning rate to 1.0535236241283278e-05.
# Epoch 117/120
# 47/47 [==============================] - 26s 564ms/step - loss: 4.4597e-04 - accuracy: 1.0000 - val_loss: 204.7770 - val_accuracy: 0.8780 - lr: 1.0535e-05
#
# Epoch 118: LearningRateScheduler setting learning rate to 1.0113826791631948e-05.
# Epoch 118/120
# 47/47 [==============================] - 26s 563ms/step - loss: 4.4446e-04 - accuracy: 1.0000 - val_loss: 204.7097 - val_accuracy: 0.8780 - lr: 1.0114e-05
#
# Epoch 119: LearningRateScheduler setting learning rate to 9.709273719966668e-06.
# Epoch 119/120
# 47/47 [==============================] - 26s 564ms/step - loss: 4.4194e-04 - accuracy: 1.0000 - val_loss: 204.8080 - val_accuracy: 0.8780 - lr: 9.7093e-06
#
# Epoch 120: LearningRateScheduler setting learning rate to 9.320902771168002e-06.
# Epoch 120/120
# 47/47 [==============================] - 26s 563ms/step - loss: 4.4032e-04 - accuracy: 1.0000 - val_loss: 204.8014 - val_accuracy: 0.8780 - lr: 9.3209e-06

# %%
test_loss, test_acc = model.evaluate(x_test_scaled, y_test)
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# 16/16 [==============================] - 2s 146ms/step - loss: 0.2201 - accuracy: 0.9540
# Test accuracy: 0.9539999961853027
# Test loss: 0.22008521854877472

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
from google.colab import files
model.save_weights('model_weights_vgg19_signLanguageDetection.h5')

# %%
model.load_weights("/content/drive/MyDrive/model_weights_vgg19_signLanguageDetection.h5")
#for loading the weights

# %%
from sklearn.metrics import classification_report
predictions = np.argmax(model.predict(x_test_scaled), axis=1)
print(classification_report(y_test,predictions))
# Out:
# 16/16 [==============================] - 17s 327ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98       106
#            1       0.97      0.96      0.97       103
#            2       0.94      1.00      0.97        93
#            3       0.98      0.94      0.96       104
#            4       0.96      0.98      0.97        94
#
#     accuracy                           0.97       500
#    macro avg       0.97      0.97      0.97       500
# weighted avg       0.97      0.97      0.97       500

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Convert model predictions to class labels (integer values)
predictions = np.argmax(model.predict(x_test_scaled), axis=1)

# Compute the confusion matrix
cm = confusion_matrix(y_test, predictions)

# Define class labels for your specific case
class_labels = ["A","B","C","D","E"]

# Plot the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues)

plt.title("Confusion Matrix")
plt.show()
# Out:
# 16/16 [==============================] - 2s 141ms/step

# %% [markdown]
# # prediction of values

# %%
test = PIL.Image.open('/content/asl_alphabet_test/asl_alphabet_test/A_test.jpg')
test
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200>

# %%
image_shape = (224,224)
test = PIL.Image.open('/content/asl_alphabet_test/asl_alphabet_test/A_test.jpg').resize(image_shape)
test
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
test = np.array(test)/255.0
test.shape
# Out:
# (224, 224, 3)

# %%
test = test[np.newaxis,...]

# %%
result=model.predict(test)
print(result)
# Out:
# 1/1 [==============================] - 1s 640ms/step
# [[1.0000000e+00 2.9114593e-20 1.3288552e-21 1.2012697e-32 1.0105269e-14
#   0.0000000e+00]]

# %%
# Results           #CORRECT PREDICTION

if(np.argmax(result)==0):
  print('A')
elif(np.argmax(result)==1):
  print('B')
elif(np.argmax(result)==2):
  print('C')
elif(np.argmax(result)==3):
  print('D')
elif(np.argmax(result)==4):
  print('E')
# Out:
# A

# %%
image_shape = (224,224)
test2 = PIL.Image.open('/content/asl_alphabet_test/asl_alphabet_test/B_test.jpg').resize(image_shape)
test2
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
test2 = np.array(test2)/255.0
test2.shape
# Out:
# (224, 224, 3)

# %%
test2 = test2[np.newaxis,...]

# %%
result2 = model.predict(test2)
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
if(np.argmax(result2)==0):
  print('A')
elif(np.argmax(result2)==1):
  print('B')
elif(np.argmax(result2)==2):
  print('C')
elif(np.argmax(result2)==3):
  print('D')                                  #CORRECT PREDICTION
elif(np.argmax(result2)==4):
  print('E')
# Out:
# B

# %%
image_shape = (224,224)
test3 = PIL.Image.open('/content/asl_alphabet_test/asl_alphabet_test/C_test.jpg').resize(image_shape)
test3
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
test3 = np.array(test3)/255.0
test3.shape
# Out:
# (224, 224, 3)

# %%
test3 = test3[np.newaxis,...]

# %%
result3 = model.predict(test3)
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
if(np.argmax(result3)==0):
  print('A')
elif(np.argmax(result3)==1):
  print('B')
elif(np.argmax(result3)==2):
  print('C')                                  #CORRECT PREDICTION
elif(np.argmax(result3)==3):
  print('D')
elif(np.argmax(result3)==4):
  print('E')
# Out:
# C
